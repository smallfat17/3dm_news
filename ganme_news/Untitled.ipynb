# %%
import json
import pandas as pd

# %%
pd.read_csv('news.json',type='series')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-df038b34d647> in <module>
# ----> 1 pd.read_csv('news.json',type='series')
#
# TypeError: parser_f() got an unexpected keyword argument 'type'

# %%
json.loads('news.json',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-9c78df7f6272> in <module>
# ----> 1 json.loads('news.json',encoding='utf-8')
#
# g:\python36-32\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# g:\python36-32\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# g:\python36-32\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
f = open('news.json',encoding='utf-8')

# %%
j = json.load(f)

# %%
df  = pd.DataFrame(j)

# %%
df['time'] = df['time'].astype('datetime64')

# %%
df.index = df['time']

# %%
del df['time']

# %%
df['2018']
# Out:
#                                                            bt  \
# time
# 2018-12-24 15:42:53            新年玩啥早知道！2019发售必玩PS4新游20款总结视频放出
# 2018-12-24 15:36:47                   《两个世界3》开发进度缓慢 玩家还需要等四年？
# 2018-12-24 15:23:48                   比游戏还吓人！国外大神蒙眼10分钟通关《逃生》
# 2018-12-24 15:18:33                   《新樱花大战》《战场女武神》属于世嘉同一开发部
# 2018-12-24 14:51:21           《勇者斗恶龙11》PS4/Switch版画面对比 后者明显缩水
# 2018-12-24 14:46:35                合奏cos 油管小哥演绎《精灵宝可梦》历代经典曲目
# 2018-12-24 14:24:53  海盗生存游戏《ATLAS》上线20万人涌入， STEAM付费崩溃新手村设计引差评
# 2018-12-24 14:24:13                  《尼尔：机械纪元》高清MOD新版本 2B更美丽了
# 2018-12-24 14:23:40             悟空仍是头号座椅！《Jump大乱斗》全新官宣PV第3弹发布
# 2018-12-24 14:10:07                 花式游戏我最棒！Xbox One四类第三方最强手柄
# 2018-12-24 14:08:03                  《宝可梦猫咪头套》扭蛋即将上市 带上主子去冒险吧
# 2018-12-24 14:03:11                 刺客世界！《怪物猎人：世界》确定联动刺客信条新预告
# 2018-12-24 13:46:48               吉尼斯世界纪录“肝帝”又有新突破 PS金奖杯数量超1万
# 2018-12-24 13:26:40                《生化危机2：重制版》宣传企划 神秘女性艾达·王介绍
# ...

# %%
import jieba
import wordcloud
import matplotlib.pyplot as plt
from scipy.misc import imread

# %%
cut_text = " ".join(jieba.cut(s))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\smallfat\AppData\Local\Temp\jieba.cache
# Loading model cost 0.649 seconds.
# Prefix dict has been built succesfully.

# %%
cloud = wordcloud.WordCloud(background_color='white',collocations=False)

# %%
word_cloud = cloud.generate(cut_text)
word_cloud.to_file('game.png')

# %%
plt.imshow(word_cloud)
plt.axis('off')
plt.show()

# %%
s_2017
# Out:
# 0
